# %%
import lvm_read
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
lvm = lvm_read.read("./LFDI.lvm")

# %%
lvm['Segments']
# Out:
# 39

# %%
mat = []
for i in range(lvm['Segments']):
    mat.append(np.array(lvm[i]['data'])[:,0])
mat = np.array(mat).T

# %%
mat.shape
# Out:
# (2000, 39)

# %%
plt.plot(range(2000), mat[:,5])

# %%
np.savetxt("./LFDI_test.csv", mat[:,0:], delimiter=",")
